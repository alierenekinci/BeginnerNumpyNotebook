# %%
import numpy as np
import matplotlib.pyplot as plt


import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# # Pi Sayısı

# %%
np.pi
# Out:
# 3.141592653589793

# %% [markdown]
# # sinx

# %%
def dereceyiradyanacevir(derece):
    return derece * (np.pi/180)

# %%
x = dereceyiradyanacevir(60)

# %%
np.sin(x) #60 derecenin sinüsü =  kök3 / 2 den 0.8660254037844386
# Out:
# 0.8660254037844386

# %%
x = dereceyiradyanacevir(90)

# %%
np.sin(x) #sin(90)=1
# Out:
# 1.0

# %% [markdown]
# ## Grafiği

# %%
fig, ax = plt.subplots(1)

#Modify the range of the grid so that it corresponds to the pi values
ax.set_xticks(np.arange(0, 2*np.pi+0.01, np.pi/4))

#Change axis labels:
labels = ['$0$', r'$\pi/4$', r'$\pi/2$', r'$3\pi/4$', r'$\pi$',
          r'$5\pi/4$', r'$3\pi/2$', r'$7\pi/4$', r'$2\pi$']
ax.set_xticklabels(labels)


#Fonksiyonumuz
x = np.linspace(0, 2*np.pi, 1001)
y = np.sin(x)
ax.plot(x, y)
plt.xlim(0, 2*np.pi)
# Out:
# (0.0, 6.283185307179586)

# %% [markdown]
# # cosx

# %%
def dereceyiradyanacevir(derece):
    return derece * (np.pi/180)

# %%
x = dereceyiradyanacevir(60)

# %%
np.cos(x) #cos(60)= 1/2 = 0.5000000000000001
# Out:
# 0.5000000000000001

# %% [markdown]
# ## Grafiği

# %%
fig, ax = plt.subplots(1)

#Modify the range of the grid so that it corresponds to the pi values
ax.set_xticks(np.arange(0, 2*np.pi+0.01, np.pi/4))

#Change axis labels:
labels = ['$0$', r'$\pi/4$', r'$\pi/2$', r'$3\pi/4$', r'$\pi$',
          r'$5\pi/4$', r'$3\pi/2$', r'$7\pi/4$', r'$2\pi$']
ax.set_xticklabels(labels)


#Fonksiyonumuz
x = np.linspace(0, 2*np.pi, 1001)
y = np.cos(x)
ax.plot(x, y)
plt.xlim(0, 2*np.pi)


plt.xlabel("x")
plt.ylabel("$cos(x)$")
plt.title("$y = cos(x)$", fontsize=14)
# Out:
# Text(0.5, 1.0, '$y = cos(x)$')

# %% [markdown]
# # tanx

# %%
def dereceyiradyanacevir(derece):
    return derece * (np.pi/180)

# %%
x = dereceyiradyanacevir(60)

# %%
np.tan(x) #tan(60)= kök3 = 1.7320508075688767
# Out:
# 1.7320508075688767

# %% [markdown]
# ## Grafiği

# %%
# .linspace arguments are (start, end, number_of_steps)
x = np.linspace(-1 * np.pi, np.pi, 1000)
y = np.tan(x)

# This operation inserts a NaN where the difference between successive points is negative
# NaN means "Not a Number" and NaNs are not plotted or connected
# I found this by doing a search for "How to plot tan(x) in matplotlib without the connecting lines between asymtotes"


plt.xlabel("x")
plt.ylabel("$tan(x)$")

# Set the x and y axis cutoffs
plt.ylim(-100,100)
plt.xlim(-1*np.pi, np.pi)

# x_labels in radians
# For a more programmatic approach to radians, see https://matplotlib.org/3.1.1/gallery/units/radian_demo.html
radian_multiples = [-1, -1/2, 0, 1/2, 1]
radians = [n * np.pi for n in radian_multiples]
radian_labels = ['$\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$']

plt.xticks(radians, radian_labels)

plt.title("$y = tan(x)$", fontsize=14)
plt.plot(x, y)
plt.show()

# %% [markdown]
# # cotx
# 1/tanx = cotx

# %%
def dereceyiradyanacevir(derece):
    return derece * (np.pi/180)

# %%
x = dereceyiradyanacevir(60)

# %%
1 / np.tan(x) #cot(60)= 1/kök3 = 0.577350269189626
# Out:
# 0.577350269189626

# %% [markdown]
# ## Grafiği

# %%
# .linspace arguments are (start, end, number_of_steps)
x = np.linspace(-1 * np.pi, np.pi, 1000)
y = 1/np.tan(x)

# This operation inserts a NaN where the difference between successive points is negative
# NaN means "Not a Number" and NaNs are not plotted or connected
# I found this by doing a search for "How to plot tan(x) in matplotlib without the connecting lines between asymtotes"


plt.xlabel("x")
plt.ylabel("$tan(x)$")

# Set the x and y axis cutoffs
plt.ylim(-10,10)
plt.xlim(-1*np.pi, np.pi)

# x_labels in radians
# For a more programmatic approach to radians, see https://matplotlib.org/3.1.1/gallery/units/radian_demo.html
radian_multiples = [-1, -1/2, 0, 1/2, 1]
radians = [n * np.pi for n in radian_multiples]
radian_labels = ['$\pi$', '$-\pi/2$', '0', '$\pi/2$', '$\pi$']

plt.xticks(radians, radian_labels)

plt.title("$y = tan(x)$", fontsize=14)
plt.plot(x, y)
plt.show()

# %% [markdown]
# # arcsinx

# %%
np.arcsin(1)     # pi/2
# Out:
# 1.5707963267948966

# %%
np.arcsin(-1)    # -pi/2
# Out:
# -1.5707963267948966

# %%
np.arcsin(0)
# Out:
# 0.0

# %% [markdown]
# ## Grafiği

# %%
arcsin_inarray = np.linspace(-1, 1, 1000) 
sin_inarray = np.linspace(-2*np.pi, 2*np.pi, 1000)

arcsin = np.arcsin(arcsin_inarray) 
sin = np.sin(sin_inarray)
  
plt.plot(arcsin_inarray, arcsin)
plt.plot(sin_inarray, sin) 

plt.xlabel("X") 
plt.ylabel("Y") 
plt.show()

# %% [markdown]
# # arccosx

# %%
np.arccos(1) # pi/2
# Out:
# 0.0

# %%
np.arccos(-1) # pi/2
# Out:
# 3.141592653589793

# %%
np.arccos(0)
# Out:
# 1.5707963267948966

# %%
arccos_inarray = np.linspace(-1, 1, 1000) 
cos_inarray = np.linspace(-2*np.pi, 2*np.pi, 1000)

arccos = np.arccos(arccos_inarray) 
cos = np.cos(cos_inarray)
  
plt.plot(arccos_inarray, arccos)
plt.plot(cos_inarray, cos) 
plt.axis('tight')
plt.xlabel("X") 
plt.ylabel("Y") 
plt.show()

# %% [markdown]
# # arctanx

# %%
np.arctan(0)
# Out:
# 0.0

# %%
np.arctan(45)
# Out:
# 1.5485777614681775

# %%
np.arctan(90)
# Out:
# 1.5596856728972892

# %%
arctan_inarray = np.linspace(-10, 10, 1000)
tan_inarray = np.linspace(0, 2*np.pi, 1000)

arctan = np.arctan(arctan_inarray) 
tan = np.tan(tan_inarray)
  
plt.plot(x, arctan)
plt.plot(x, tan) 

plt.ylim(-10,10)
plt.xlim(-3, 3)

plt.xlabel("X") 
plt.ylabel("Y") 
plt.show()

# %% [markdown]
# ## arctan2(x1,x2)

# %%
x1, x2 = 3,4
np.arctan2(x1,x2)
# Out:
# 0.6435011087932844

# %% [markdown]
# ## sqrt

# %%
np.sqrt(50)
# Out:
# 7.0710678118654755

# %%
np.sqrt(49)
# Out:
# 7.0

# %% [markdown]
# ## exp
# e^x hesaplar.

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
np.exp(2)
# Out:
# 7.38905609893065

# %% [markdown]
# # log

# %%
np.log(2) #ln2
# Out:
# 0.6931471805599453

# %%
np.log(2)/np.log(10) #log_10(2) = 0.30102999566398114
# Out:
# 0.30102999566398114

# %%
np.log(3)/np.log(5) #log_5(3) = 0.6826061944859854
# Out:
# 0.6826061944859854

# %% [markdown]
# # Burdaki tüm fonksiyonları matrisleri kullanarak hesaplatalım.

# %%
a = np.linspace(1,10,14)

# %%
a
# Out:
# array([ 1.        ,  1.69230769,  2.38461538,  3.07692308,  3.76923077,
#         4.46153846,  5.15384615,  5.84615385,  6.53846154,  7.23076923,
#         7.92307692,  8.61538462,  9.30769231, 10.        ])

# %%
np.sin(a)
# Out:
# array([ 0.84147098,  0.99262657,  0.68672732,  0.06462451, -0.58723465,
#        -0.96870165, -0.90413004, -0.4232518 ,  0.2525127 ,  0.81200774,
#         0.99761387,  0.72386875,  0.11681831, -0.54402111])

# %%
np.cos(a)
# Out:
# array([ 0.54030231, -0.12121257, -0.72691512, -0.99790965, -0.80941675,
#        -0.24822795,  0.42725739,  0.90601209,  0.96759358,  0.58364666,
#        -0.06904032, -0.6899377 , -0.9931533 , -0.83907153])

# %%
np.tan(a)
# Out:
# array([  1.55740772,  -8.18913913,  -0.94471459,  -0.06475988,
#          0.72550346,   3.9024681 ,  -2.11612497,  -0.46715911,
#          0.26096979,   1.39126597, -14.44972761,  -1.04917988,
#         -0.11762365,   0.64836083])

# %%
1/np.tan(a)#cot(x)
# Out:
# array([  0.64209262,  -0.12211296,  -1.05852076, -15.44165914,
#          1.37835318,   0.25624809,  -0.47256188,  -2.14059831,
#          3.83186109,   0.71876983,  -0.06920546,  -0.9531254 ,
#         -8.50169178,   1.54235105])

# %%
np.sqrt(a)
# Out:
# array([1.        , 1.30088727, 1.54421999, 1.75411604, 1.94145069,
#        2.11223542, 2.27020839, 2.4178821 , 2.55704156, 2.68900897,
#        2.81479607, 2.93519754, 3.05085108, 3.16227766])

# %%
np.log(a)
# Out:
# array([0.        , 0.5260931 , 0.86903785, 1.1239301 , 1.32687094,
#        1.49549365, 1.63974326, 1.76578398, 1.8777019 , 1.97834542,
#        2.06977963, 2.15354951, 2.23084119, 2.30258509])

# %%
np.exp(a)
# Out:
# array([2.71828183e+00, 5.43200164e+00, 1.08548869e+01, 2.16915564e+01,
#        4.33467084e+01, 8.66206692e+01, 1.73095965e+02, 3.45901429e+02,
#        6.91222341e+02, 1.38128462e+03, 2.76025107e+03, 5.51586969e+03,
#        1.10224823e+04, 2.20264658e+04])

# %%
a = np.linspace(-1,1,10)

# %%
a
# Out:
# array([-1.        , -0.77777778, -0.55555556, -0.33333333, -0.11111111,
#         0.11111111,  0.33333333,  0.55555556,  0.77777778,  1.        ])

# %%
np.arcsin(a)
# Out:
# array([-1.57079633, -0.89112251, -0.58903097, -0.33983691, -0.11134101,
#         0.11134101,  0.33983691,  0.58903097,  0.89112251,  1.57079633])

# %%
np.arccos(a)
# Out:
# array([3.14159265, 2.46191883, 2.1598273 , 1.91063324, 1.68213734,
#        1.45945531, 1.23095942, 0.98176536, 0.67967382, 0.        ])

# %%
np.arctan(a)
# Out:
# array([-0.78539816, -0.66104317, -0.5070985 , -0.32175055, -0.11065722,
#         0.11065722,  0.32175055,  0.5070985 ,  0.66104317,  0.78539816])

# %%
#Matematiksel işlemler çok rahatlıkla yapılabiliyor

# %% [markdown]
# # Matrislerde işlemler

# %%
a = np.array([3+2j, 4+ 1j, 9-2j])

# %% [markdown]
# ## real

# %%
c = np.real(a)
print(a,c, sep="\n")
# Out:
# [3.+2.j 4.+1.j 9.-2.j]
# [3. 4. 9.]

# %% [markdown]
# ## imag

# %%
c = np.imag(a)
print(a,c, sep="\n")
# Out:
# [3.+2.j 4.+1.j 9.-2.j]
# [ 2.  1. -2.]

# %% [markdown]
# ## conj

# %%
c = np.conj(a)
print(a,c, sep="\n")
# Out:
# [3.+2.j 4.+1.j 9.-2.j]
# [3.-2.j 4.-1.j 9.+2.j]

# %% [markdown]
# Tekrar tanımlayalım

# %%
np.random.seed(int(np.ceil(np.random.uniform(845,8797653))))#işin pisliği sayıyı karıştırdıkca karıştırayım dedim
a = np.random.randint(2,18,size=18)

# %%
a
# Out:
# array([14, 11, 13,  2,  5,  9, 13, 10,  9,  5,  3, 13,  6,  4, 14,  7,  4,
#         4])

# %%
x = np.linspace(-4,4,5)

# %%
y = np.sign(x)

# %%
print(x,y,sep="\n")
# Out:
# [-4. -2.  0.  2.  4.]
# [-1. -1.  0.  1.  1.]

# %% [markdown]
# ## sum
# Tüm sayıları topla

# %%
np.sum(a)
# Out:
# 146

# %%
a.sum()
# Out:
# 146

# %%
c = np.random.randint(2,18,size=(8,4))

# %%
c
# Out:
# array([[13,  5,  7,  7],
#        [10,  7,  8, 15],
#        [ 2, 10,  8,  8],
#        [ 8, 17, 11,  9],
#        [12, 15,  9, 15],
#        [15, 11, 11,  9],
#        [12, 11, 15, 17],
#        [11, 14, 10, 16]])

# %%
c.sum(axis=0)#sutun boyunca topla
# Out:
# array([83, 90, 79, 96])

# %%
np.sum(c, axis=0)
# Out:
# array([83, 90, 79, 96])

# %%
np.sum(c)
# Out:
# 348

# %%
c.sum(axis=1)#satır boyunca topla
# Out:
# array([32, 40, 28, 45, 51, 46, 55, 51])

# %%
np.sum(c,axis=1)
# Out:
# array([32, 40, 28, 45, 51, 46, 55, 51])

# %%
np.sum(c)
# Out:
# 348

# %% [markdown]
# ## prod
# Tüm sayıları çarp

# %%
np.prod(a)
# Out:
# 1546978777344000

# %%
a.prod()
# Out:
# 1546978777344000

# %% [markdown]
# ## mean
# Ortalamasını al

# %%
np.mean(a)
# Out:
# 8.11111111111111

# %%
a.mean()
# Out:
# 8.11111111111111

# %% [markdown]
# ## var
# Varyansını al

# %%
np.var(a)
# Out:
# 16.320987654320984

# %%
a.var()
# Out:
# 16.320987654320984

# %% [markdown]
# ## std
# Standart sapmasını hesaplayabilirsin

# %%
np.std(a)
# Out:
# 4.039924213932854

# %%
a.std()
# Out:
# 4.039924213932854

# %% [markdown]
# ## cumsum
# Kümülatif toplamı verir

# %%
a
# Out:
# array([14, 11, 13,  2,  5,  9, 13, 10,  9,  5,  3, 13,  6,  4, 14,  7,  4,
#         4])

# %%
np.cumsum(a)
# Out:
# array([ 14,  25,  38,  40,  45,  54,  67,  77,  86,  91,  94, 107, 113,
#        117, 131, 138, 142, 146])

# %% [markdown]
# ## cumprod
# Kümülatif Çarpım diyebiliriz .dasdasda

# %%
a
# Out:
# array([14, 11, 13,  2,  5,  9, 13, 10,  9,  5,  3, 13,  6,  4, 14,  7,  4,
#         4])

# %%
np.cumprod(a)
# Out:
# array([              14,              154,             2002,
#                    4004,            20020,           180180,
#                 2342340,         23423400,        210810600,
#              1054053000,       3162159000,      41108067000,
#            246648402000,     986593608000,   13812310512000,
#          96686173584000,  386744694336000, 1546978777344000])

# %% [markdown]
# ## min
# Adı üstünde en küçüğü verir.

# %%
a.min()
# Out:
# 2

# %%
np.min(a)
# Out:
# 2

# %% [markdown]
# ## max
# Adı üstünde en büyüğü verir.

# %%
a.max()
# Out:
# 14

# %%
np.max(a)
# Out:
# 14

# %% [markdown]
# ## maximum

# %%
np.maximum(12,14)#iki değer veya iki array arasındaki max ı basar.Yani iki diziyi karşılaştırıp küçük değerleriyle yeni dizi oluşturma
# Out:
# 14

# %%
b = np.random.randint(2,18,size=18)
print(a, b, sep="\n")
# Out:
# [14 11 13  2  5  9 13 10  9  5  3 13  6  4 14  7  4  4]
# [16 15  6  6 15 16  7  2 13  4  5 10 10 14  8  6  3  9]

# %%
np.maximum(a,b)
# Out:
# array([16, 15, 13,  6, 15, 16, 13, 10, 13,  5,  5, 13, 10, 14, 14,  7,  4,
#         9])

# %% [markdown]
# ## minimum

# %%
print(a, b, sep="\n")
# Out:
# [14 11 13  2  5  9 13 10  9  5  3 13  6  4 14  7  4  4]
# [16 15  6  6 15 16  7  2 13  4  5 10 10 14  8  6  3  9]

# %%
np.minimum(a,b)#iki değer veya iki array arasındaki min i basar
# Out:
# array([14, 11,  6,  2,  5,  9,  7,  2,  9,  4,  3, 10,  6,  4,  8,  6,  3,
#         4])

# %% [markdown]
# ## argmin

# %%
print(a)
np.argmin(a) #En küçük değerin eleman indisi
# Out:
# [14 11 13  2  5  9 13 10  9  5  3 13  6  4 14  7  4  4]
# 3

# %%
print(b)
np.argmin(b) #En küçük değerin eleman indisi ilk hangisi ile onu basar
# Out:
# [16 15  6  6 15 16  7  2 13  4  5 10 10 14  8  6  3  9]
# 7

# %% [markdown]
# ## argmax

# %%
print(a)
np.argmax(a)
# Out:
# [14 11 13  2  5  9 13 10  9  5  3 13  6  4 14  7  4  4]
# 0

# %%
print(b)
np.argmax(b)
# Out:
# [16 15  6  6 15 16  7  2 13  4  5 10 10 14  8  6  3  9]
# 0

# %% [markdown]
# ## all
# Dizinin hepsi true ise true dönecektir. Bir tanesi bile false ise false döner.

# %%
sorgu = a > 0

# %%
np.all(sorgu)
# Out:
# True

# %%
sorgu = a < 8

# %%
print(a, sorgu, sep="\n")
# Out:
# [14 11 13  2  5  9 13 10  9  5  3 13  6  4 14  7  4  4]
# [False False False  True  True False False False False  True  True False
#   True  True False  True  True  True]

# %%
np.all(sorgu)
# Out:
# False

# %% [markdown]
# ## any
# Bir tane bile true varsa true döner

# %%
print(a, sorgu, sep="\n")
# Out:
# [14 11 13  2  5  9 13 10  9  5  3 13  6  4 14  7  4  4]
# [False False False  True  True False False False False  True  True False
#   True  True False  True  True  True]

# %%
np.any(sorgu)
# Out:
# True

# %%
sorgu = a < 0

# %%
print(a, sorgu, sep="\n")
# Out:
# [14 11 13  2  5  9 13 10  9  5  3 13  6  4 14  7  4  4]
# [False False False False False False False False False False False False
#  False False False False False False]

# %%
np.any(sorgu)
# Out:
# False

# %% [markdown]
# ## sort

# %%
a
# Out:
# array([14, 11, 13,  2,  5,  9, 13, 10,  9,  5,  3, 13,  6,  4, 14,  7,  4,
#         4])

# %%
np.sort(a)
# Out:
# array([ 2,  3,  4,  4,  4,  5,  5,  6,  7,  9,  9, 10, 11, 13, 13, 13, 14,
#        14])

# %%
a
# Out:
# array([14, 11, 13,  2,  5,  9, 13, 10,  9,  5,  3, 13,  6,  4, 14,  7,  4,
#         4])

# %%
a.sort()

# %%
a
# Out:
# array([ 2,  3,  4,  4,  4,  5,  5,  6,  7,  9,  9, 10, 11, 13, 13, 13, 14,
#        14])
